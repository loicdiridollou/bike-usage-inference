# %%
import yaml
import requests
import pandas as pd

# %%
API_KEY = yaml.full_load(open('creds.yaml', 'r'))['maps_api']

# %%
dd = requests.get('https://gbfs.baywheels.com/gbfs/en/station_information.json')
stations = pd.DataFrame(dd.json()['data']['stations'])

# %%
stations.loc[stations['name'].str.contains('Caltrain')]
# Out:
#     station_type legacy_id  electric_bike_surcharge_waiver  \
# 128      classic       465                           False
# 237      classic       130                           False
# 364      classic        30                           False
#
#     eightd_station_services short_name                           external_id  \
# 128                      []   SF-J29-3  a7da1857-747a-4507-9d8f-2a9f95f0babf
# 237                      []     SF-P30  e7691d93-eed6-4388-b681-00ae0b455d23
# 364                      []     SF-J29  ea11aa7f-c070-46a4-a074-70604340efa2
#
#             lon                                               name  \
# 128 -122.394495  San Francisco Caltrain Station (King St at 4th...
# 237 -122.391885                           22nd St Caltrain Station
# 364 -122.395282     San Francisco Caltrain (Townsend St at 4th St)
#
#                                station_id  has_kiosk  capacity region_id  \
# 128  a7da1857-747a-4507-9d8f-2a9f95f0babf       True        18         3
# 237  e7691d93-eed6-4388-b681-00ae0b455d23       True        35         3
# 364  ea11aa7f-c070-46a4-a074-70604340efa2       True        19         3
#
#                                            rental_uris     rental_methods  \
# 128  {'android': 'https://sfo.lft.to/lastmile_qr_sc...  [KEY, CREDITCARD]
# 237  {'android': 'https://sfo.lft.to/lastmile_qr_sc...  [KEY, CREDITCARD]
# 364  {'android': 'https://sfo.lft.to/lastmile_qr_sc...  [KEY, CREDITCARD]
#
#      eightd_has_key_dispenser        lat
# 128                     False  37.776311
# 237                     False  37.757704
# 364                     False  37.776598

# %%
lat1, lon1 = stations.loc[stations['name'] == 'Commercial St at Montgomery St'][['lat', 'lon']].iloc[0]

# %%
lat2, lon2 = stations.loc[stations['name'] == 'San Francisco Caltrain Station (King St at 4th St)'][['lat', 'lon']].iloc[0]

# %%
req = requests.get("https://maps.googleapis.com/maps/api/directions/json?avoid=highways&destination={},{}&mode=bicycling&origin={},{}&key={}".format(lat1, lon1, lat2, lon2, API_KEY))

# %%
res = req.json()

# %%
res
# Out:
# {'geocoded_waypoints': [{'geocoder_status': 'OK',
#    'place_id': 'ChIJiZsGldZ_j4ARSAUO2zvLtxM',
#    'types': ['establishment', 'point_of_interest']},
#   {'geocoder_status': 'OK',
#    'place_id': 'ChIJAyk-84qAhYARoYww6NIvE6A',
#    'types': ['establishment', 'point_of_interest']}],
#  'routes': [{'bounds': {'northeast': {'lat': 37.7968933, 'lng': -122.3875728},
#     'southwest': {'lat': 37.7762883, 'lng': -122.4028589}},
#    'copyrights': 'Map data ©2022 Google',
#    'legs': [{'distance': {'text': '2.4 mi', 'value': 3849},
#      'duration': {'text': '15 mins', 'value': 920},
#      'end_address': 'Commercial St at Montgomery St, San Francisco, CA 94111, USA',
#      'end_location': {'lat': 37.7942628, 'lng': -122.4028589},
#      'start_address': 'San Francisco Caltrain Station (King St at 4th St), San Francisco, CA 94107, USA',
#      'start_location': {'lat': 37.7762883, 'lng': -122.394524},
#      'steps': [{'distance': {'text': '308 ft', 'value': 94},
#        'duration': {'text': '1 min', 'value': 17},
#        'end_location': {'lat': 37.7768963, 'lng': -122.3952745},
#        'html_instructions': 'Head <b>northwest</b> toward <b>San Francisco Bicycle Rte 36</b>/<wbr/><b>Townsend St</b>',
#        'polyline': {'points': 'ydqeFvd`jVMRY^W^[^]`@'},
#        'start_location': {'lat': 37.7762883, 'lng': -122.394524},
#        'travel_mode': 'BICYCLING'},
#       {'distance': {'text': '0.4 mi', 'value': 588},
#        'duration': {'text': '4 mins', 'value': 219},
#        'end_location': {'lat': 37.7806303, 'lng': -122.3905427},
#        'html_instructions': 'Turn <b>right</b> onto <b>San Francisco Bicycle Rte 36</b>/<wbr/><b>Townsend St</b>',
#        'maneuver': 'turn-right',
#        'polyline': {'points': 'shqeFli`jVa@k@OUOUg@q@q@{@u@cAEEEGm@{@c@m@CE]g@u@cAk@s@g@q@yAqBCGqAcBGKk@u@i@w@'},
#        'start_location': {'lat': 37.7768963, 'lng': -122.3952745},
#        'travel_mode': 'BICYCLING'},
#       {'distance': {'text': '436 ft', 'value': 133},
#        'duration': {'text': '1 min', 'value': 65},
#        'end_location': {'lat': 37.7797849, 'lng': -122.3894709},
#        'html_instructions': 'Turn <b>right</b> onto <b>2nd St</b>/<wbr/><b>San Francisco Bicycle Rte 11</b><div style="font-size:0.9em">Continue to follow San Francisco Bicycle Rte 11</div>',
#        'maneuver': 'turn-right',
#        'polyline': {'points': '}_reFzk_jVHMr@aABCLQh@s@NQJODEBEHM'},
#        'start_location': {'lat': 37.7806303, 'lng': -122.3905427},
#        'travel_mode': 'BICYCLING'},
#       {'distance': {'text': '0.3 mi', 'value': 448},
#        'duration': {'text': '2 mins', 'value': 95},
#        'end_location': {'lat': 37.7834764, 'lng': -122.3879958},
#        'html_instructions': 'Turn <b>left</b> onto <b>King St</b>/<wbr/><b>San Francisco Bicycle Rte 5</b><div style="font-size:0.9em">Continue to follow San Francisco Bicycle Rte 5</div>',
#        'maneuver': 'turn-left',
#        'polyline': {'points': 'szqeFde_jV[a@_AoACEMMKKGGKIMKGEKGOKAAIEECECGCOGQGKCA@q@MG?CAIAm@CMA[CQAYAK?OAQ?QAoBGSAYCi@C'},
#        'start_location': {'lat': 37.7797849, 'lng': -122.3894709},
#        'travel_mode': 'BICYCLING'},
#       {'distance': {'text': '23 ft', 'value': 7},
#        'duration': {'text': '1 min', 'value': 1},
#        'end_location': {'lat': 37.7834689, 'lng': -122.3879157},
#        'html_instructions': 'Turn <b>right</b> toward <b>Herb Caen Way</b>/<wbr/><b>San Francisco Bay Trail</b>',
#        'maneuver': 'turn-right',
#        'polyline': {'points': 'wqreF~{~iV@O'},
#        'start_location': {'lat': 37.7834764, 'lng': -122.3879958},
#        'travel_mode': 'BICYCLING'},
#       {'distance': {'text': '0.9 mi', 'value': 1507},
#        'duration': {'text': '4 mins', 'value': 265},
#        'end_location': {'lat': 37.7953684, 'lng': -122.3937889},
#        'html_instructions': 'Turn <b>left</b> onto <b>Herb Caen Way</b>/<wbr/><b>San Francisco Bay Trail</b><div style="font-size:0.9em">Continue to follow San Francisco Bay Trail</div>',
#        'maneuver': 'turn-left',
#        'polyline': {'points': 'uqreFn{~iVc@CoCKs@EUA_DMkBIc@CA?eAEc@Aw@Ce@CQ?QAQ?I?Y@G?i@BUBA?YDE@c@HE?]Fa@HI@YFI@WHSHUJULGFIFGHCBOLMLKHKFy@^oAh@eBt@EBQJEBGDKJSZsCjDs@~@[`@MP_CzC}@dAe@h@[Z{@x@}@`AQPq@n@eB~A'},
#        'start_location': {'lat': 37.7834689, 'lng': -122.3879157},
#        'travel_mode': 'BICYCLING'},
#       {'distance': {'text': '0.1 mi', 'value': 211},
#        'duration': {'text': '1 min', 'value': 37},
#        'end_location': {'lat': 37.7968933, 'lng': -122.3952103},
#        'html_instructions': 'Continue straight to stay on <b>San Francisco Bay Trail</b>',
#        'maneuver': 'straight',
#        'polyline': {'points': 'a|teFd``jVqCbCwAtAq@n@SP'},
#        'start_location': {'lat': 37.7953684, 'lng': -122.3937889},
#        'travel_mode': 'BICYCLING'},
#       {'distance': {'text': '0.4 mi', 'value': 588},
#        'duration': {'text': '3 mins', 'value': 171},
#        'end_location': {'lat': 37.7957404, 'lng': -122.4016876},
#        'html_instructions': 'Turn <b>left</b> onto <b>Washington St</b>',
#        'maneuver': 'turn-left',
#        'polyline': {'points': 'qeueF`i`jVLVXv@DP@D@D@F?HDn@Dj@Fj@Nv@JRBVDZTdDFd@JpAFr@?@Dn@@@HxABXRbDLtBBZ@XF|@'},
#        'start_location': {'lat': 37.7968933, 'lng': -122.3952103},
#        'travel_mode': 'BICYCLING'},
#       {'distance': {'text': '482 ft', 'value': 147},
#        'duration': {'text': '1 min', 'value': 27},
#        'end_location': {'lat': 37.794436, 'lng': -122.4014404},
#        'html_instructions': 'Turn <b>left</b> onto <b>San Francisco Bicycle Rte 11</b>/<wbr/><b>Sansome St</b>',
#        'maneuver': 'turn-left',
#        'polyline': {'points': 'k~teFpqajVd@Gn@GxASrAM'},
#        'start_location': {'lat': 37.7957404, 'lng': -122.4016876},
#        'travel_mode': 'BICYCLING'},
#       {'distance': {'text': '413 ft', 'value': 126},
#        'duration': {'text': '1 min', 'value': 23},
#        'end_location': {'lat': 37.7942628, 'lng': -122.4028589},
#        'html_instructions': 'Turn <b>right</b> onto <b>Commercial St</b><div style="font-size:0.9em">Turn is not allowed Mon–Fri 11:00 AM – 2:00 PM</div>',
#        'maneuver': 'turn-right',
#        'polyline': {'points': 'gvteF~oajVBR@`@@F?JHpA@LHpAD^'},
#        'start_location': {'lat': 37.794436, 'lng': -122.4014404},
#        'travel_mode': 'BICYCLING'}],
#      'traffic_speed_entry': [],
#      'via_waypoint': []}],
#    'overview_polyline': {'points': 'ydqeFvd`jV{ArB]`@a@k@_@k@uCwD{AwBgDqEwDiFuAmB|@oAjA{A^i@mBeCm@i@e@[]Qa@OMAgAQiBKgACaCIm@Ei@C@OsDOuI_@qGU}@@{AL}Ch@k@Rk@X]\\i@d@{FfCe@XgFrGgFtGaAdAyBzB{HdHiCdCSPLV^hABJLlBVbBJRBVZ`ERvBNfBn@lKDt@F|@d@GhC[rAMBRBh@H|AP~B'},
#    'summary': 'San Francisco Bay Trail',
#    'warnings': ["Bicycling directions are in beta. Use caution – This route may contain streets that aren't suited for bicycling."],
#    'waypoint_order': []}],
#  'status': 'OK'}

# %%
res.keys()
# Out:
# dict_keys(['geocoded_waypoints', 'routes', 'status'])

# %%
import datetime as dt

str(dt.timedelta(seconds=res['routes'][0]['legs'][0]['duration']['value']))
# Out:
# '0:15:20'

# %%
def convert_sec_to_time(num_sec):
    return str(dt.timedelta(seconds=res['routes'][0]['legs'][0]['duration']['value']))


def get_travel_time(req):
    return req['routes'][0]['legs'][0]['duration']['value']


def get_stations_coord(name, stations_df):
    if name in stations_df['name'].values:
        return stations_df.loc[stations_df['name'] == name][['lat', 'lon']].iloc[0]
    return None, None

def make_request(station1, station2, stations_df):
    lat1, lon1 = get_stations_coord(station1, stations_df)
    lat2, lon2 = get_stations_coord(station2, stations_df)
    
    req = requests.get("https://maps.googleapis.com/maps/api/directions/json?avoid=highways&destination={},{}&mode=bicycling&origin={},{}&key={}".format(lat1, lon1, lat2, lon2, API_KEY))
    
    return req.json()

# %%
lat, lon = get_stations_coord('Commercial St at Montgomery St', stations)

# %%
make_request('Commercial St at Montgomery St', 'San Francisco Caltrain Station (King St at 4th St)', stations)
# Out:
# {'geocoded_waypoints': [{'geocoder_status': 'OK',
#    'place_id': 'ChIJiZsGldZ_j4ARSAUO2zvLtxM',
#    'types': ['establishment', 'point_of_interest']},
#   {'geocoder_status': 'OK',
#    'place_id': 'ChIJAyk-84qAhYARoYww6NIvE6A',
#    'types': ['establishment', 'point_of_interest']}],
#  'routes': [{'bounds': {'northeast': {'lat': 37.7968933, 'lng': -122.3875728},
#     'southwest': {'lat': 37.7762883, 'lng': -122.4028589}},
#    'copyrights': 'Map data ©2022 Google',
#    'legs': [{'distance': {'text': '2.4 mi', 'value': 3849},
#      'duration': {'text': '15 mins', 'value': 920},
#      'end_address': 'Commercial St at Montgomery St, San Francisco, CA 94111, USA',
#      'end_location': {'lat': 37.7942628, 'lng': -122.4028589},
#      'start_address': 'San Francisco Caltrain Station (King St at 4th St), San Francisco, CA 94107, USA',
#      'start_location': {'lat': 37.7762883, 'lng': -122.394524},
#      'steps': [{'distance': {'text': '308 ft', 'value': 94},
#        'duration': {'text': '1 min', 'value': 17},
#        'end_location': {'lat': 37.7768963, 'lng': -122.3952745},
#        'html_instructions': 'Head <b>northwest</b> toward <b>San Francisco Bicycle Rte 36</b>/<wbr/><b>Townsend St</b>',
#        'polyline': {'points': 'ydqeFvd`jVMRY^W^[^]`@'},
#        'start_location': {'lat': 37.7762883, 'lng': -122.394524},
#        'travel_mode': 'BICYCLING'},
#       {'distance': {'text': '0.4 mi', 'value': 588},
#        'duration': {'text': '4 mins', 'value': 219},
#        'end_location': {'lat': 37.7806303, 'lng': -122.3905427},
#        'html_instructions': 'Turn <b>right</b> onto <b>San Francisco Bicycle Rte 36</b>/<wbr/><b>Townsend St</b>',
#        'maneuver': 'turn-right',
#        'polyline': {'points': 'shqeFli`jVa@k@OUOUg@q@q@{@u@cAEEEGm@{@c@m@CE]g@u@cAk@s@g@q@yAqBCGqAcBGKk@u@i@w@'},
#        'start_location': {'lat': 37.7768963, 'lng': -122.3952745},
#        'travel_mode': 'BICYCLING'},
#       {'distance': {'text': '436 ft', 'value': 133},
#        'duration': {'text': '1 min', 'value': 65},
#        'end_location': {'lat': 37.7797849, 'lng': -122.3894709},
#        'html_instructions': 'Turn <b>right</b> onto <b>2nd St</b>/<wbr/><b>San Francisco Bicycle Rte 11</b><div style="font-size:0.9em">Continue to follow San Francisco Bicycle Rte 11</div>',
#        'maneuver': 'turn-right',
#        'polyline': {'points': '}_reFzk_jVHMr@aABCLQh@s@NQJODEBEHM'},
#        'start_location': {'lat': 37.7806303, 'lng': -122.3905427},
#        'travel_mode': 'BICYCLING'},
#       {'distance': {'text': '0.3 mi', 'value': 448},
#        'duration': {'text': '2 mins', 'value': 95},
#        'end_location': {'lat': 37.7834764, 'lng': -122.3879958},
#        'html_instructions': 'Turn <b>left</b> onto <b>King St</b>/<wbr/><b>San Francisco Bicycle Rte 5</b><div style="font-size:0.9em">Continue to follow San Francisco Bicycle Rte 5</div>',
#        'maneuver': 'turn-left',
#        'polyline': {'points': 'szqeFde_jV[a@_AoACEMMKKGGKIMKGEKGOKAAIEECECGCOGQGKCA@q@MG?CAIAm@CMA[CQAYAK?OAQ?QAoBGSAYCi@C'},
#        'start_location': {'lat': 37.7797849, 'lng': -122.3894709},
#        'travel_mode': 'BICYCLING'},
#       {'distance': {'text': '23 ft', 'value': 7},
#        'duration': {'text': '1 min', 'value': 1},
#        'end_location': {'lat': 37.7834689, 'lng': -122.3879157},
#        'html_instructions': 'Turn <b>right</b> toward <b>Herb Caen Way</b>/<wbr/><b>San Francisco Bay Trail</b>',
#        'maneuver': 'turn-right',
#        'polyline': {'points': 'wqreF~{~iV@O'},
#        'start_location': {'lat': 37.7834764, 'lng': -122.3879958},
#        'travel_mode': 'BICYCLING'},
#       {'distance': {'text': '0.9 mi', 'value': 1507},
#        'duration': {'text': '4 mins', 'value': 265},
#        'end_location': {'lat': 37.7953684, 'lng': -122.3937889},
#        'html_instructions': 'Turn <b>left</b> onto <b>Herb Caen Way</b>/<wbr/><b>San Francisco Bay Trail</b><div style="font-size:0.9em">Continue to follow San Francisco Bay Trail</div>',
#        'maneuver': 'turn-left',
#        'polyline': {'points': 'uqreFn{~iVc@CoCKs@EUA_DMkBIc@CA?eAEc@Aw@Ce@CQ?QAQ?I?Y@G?i@BUBA?YDE@c@HE?]Fa@HI@YFI@WHSHUJULGFIFGHCBOLMLKHKFy@^oAh@eBt@EBQJEBGDKJSZsCjDs@~@[`@MP_CzC}@dAe@h@[Z{@x@}@`AQPq@n@eB~A'},
#        'start_location': {'lat': 37.7834689, 'lng': -122.3879157},
#        'travel_mode': 'BICYCLING'},
#       {'distance': {'text': '0.1 mi', 'value': 211},
#        'duration': {'text': '1 min', 'value': 37},
#        'end_location': {'lat': 37.7968933, 'lng': -122.3952103},
#        'html_instructions': 'Continue straight to stay on <b>San Francisco Bay Trail</b>',
#        'maneuver': 'straight',
#        'polyline': {'points': 'a|teFd``jVqCbCwAtAq@n@SP'},
#        'start_location': {'lat': 37.7953684, 'lng': -122.3937889},
#        'travel_mode': 'BICYCLING'},
#       {'distance': {'text': '0.4 mi', 'value': 588},
#        'duration': {'text': '3 mins', 'value': 171},
#        'end_location': {'lat': 37.7957404, 'lng': -122.4016876},
#        'html_instructions': 'Turn <b>left</b> onto <b>Washington St</b>',
#        'maneuver': 'turn-left',
#        'polyline': {'points': 'qeueF`i`jVLVXv@DP@D@D@F?HDn@Dj@Fj@Nv@JRBVDZTdDFd@JpAFr@?@Dn@@@HxABXRbDLtBBZ@XF|@'},
#        'start_location': {'lat': 37.7968933, 'lng': -122.3952103},
#        'travel_mode': 'BICYCLING'},
#       {'distance': {'text': '482 ft', 'value': 147},
#        'duration': {'text': '1 min', 'value': 27},
#        'end_location': {'lat': 37.794436, 'lng': -122.4014404},
#        'html_instructions': 'Turn <b>left</b> onto <b>San Francisco Bicycle Rte 11</b>/<wbr/><b>Sansome St</b>',
#        'maneuver': 'turn-left',
#        'polyline': {'points': 'k~teFpqajVd@Gn@GxASrAM'},
#        'start_location': {'lat': 37.7957404, 'lng': -122.4016876},
#        'travel_mode': 'BICYCLING'},
#       {'distance': {'text': '413 ft', 'value': 126},
#        'duration': {'text': '1 min', 'value': 23},
#        'end_location': {'lat': 37.7942628, 'lng': -122.4028589},
#        'html_instructions': 'Turn <b>right</b> onto <b>Commercial St</b><div style="font-size:0.9em">Turn is not allowed Mon–Fri 11:00 AM – 2:00 PM</div>',
#        'maneuver': 'turn-right',
#        'polyline': {'points': 'gvteF~oajVBR@`@@F?JHpA@LHpAD^'},
#        'start_location': {'lat': 37.794436, 'lng': -122.4014404},
#        'travel_mode': 'BICYCLING'}],
#      'traffic_speed_entry': [],
#      'via_waypoint': []}],
#    'overview_polyline': {'points': 'ydqeFvd`jV{ArB]`@a@k@_@k@uCwD{AwBgDqEwDiFuAmB|@oAjA{A^i@mBeCm@i@e@[]Qa@OMAgAQiBKgACaCIm@Ei@C@OsDOuI_@qGU}@@{AL}Ch@k@Rk@X]\\i@d@{FfCe@XgFrGgFtGaAdAyBzB{HdHiCdCSPLV^hABJLlBVbBJRBVZ`ERvBNfBn@lKDt@F|@d@GhC[rAMBRBh@H|AP~B'},
#    'summary': 'San Francisco Bay Trail',
#    'warnings': ["Bicycling directions are in beta. Use caution – This route may contain streets that aren't suited for bicycling."],
#    'waypoint_order': []}],
#  'status': 'OK'}

# %%
lat1, lon1 = [3.77860194e+01, -1.22403728e+02]

# %%
def manhattan_distance(a, b):
    return sum(abs(val1-val2) for val1, val2 in zip(a,b))

# %%
manhattan_distance([3.77860194e+01, -1.22403728e+02], [3.77880194e+01, -1.22423728e+02])
# Out:
# 0.021999999999998465

# %%
stations.apply(lambda x: manhattan_distance([x.lat, x.lon], [3.77860194e+01, -1.22403728e+02]), axis=1).argmin()
# Out:
# 395

# %%
stations.iloc[395]
# Out:
# rental_uris                       {'android': 'https://sfo.lft.to/lastmile_qr_sc...
# station_id                                     1b13a386-c5f4-42cc-bc3b-ded95982e090
# electric_bike_surcharge_waiver                                                False
# has_kiosk                                                                      True
# region_id                                                                         3
# eightd_station_services                                                          []
# lon                                                                     -122.405234
# capacity                                                                         35
# lat                                                                       37.786138
# short_name                                                                   SF-G27
# eightd_has_key_dispenser                                                      False
# name                                   Powell St BART Station (Market St at 4th St)
# external_id                                    1b13a386-c5f4-42cc-bc3b-ded95982e090
# legacy_id                                                                         3
# rental_methods                                                    [KEY, CREDITCARD]
# station_type                                                                classic
# Name: 395, dtype: object

# %%
stations
# Out:
#                                            rental_uris  \
# 0    {'android': 'https://sfo.lft.to/lastmile_qr_sc...
# 1    {'android': 'https://sfo.lft.to/lastmile_qr_sc...
# 2    {'android': 'https://sfo.lft.to/lastmile_qr_sc...
# 3    {'android': 'https://sfo.lft.to/lastmile_qr_sc...
# 4    {'android': 'https://sfo.lft.to/lastmile_qr_sc...
# ..                                                 ...
# 489  {'android': 'https://sfo.lft.to/lastmile_qr_sc...
# 490  {'android': 'https://sfo.lft.to/lastmile_qr_sc...
# 491  {'android': 'https://sfo.lft.to/lastmile_qr_sc...
# 492  {'android': 'https://sfo.lft.to/lastmile_qr_sc...
# 493  {'android': 'https://sfo.lft.to/lastmile_qr_sc...
#
#                                station_id  electric_bike_surcharge_waiver  \
# 0    0d730ac1-7ce6-45cf-aca6-b412ea46709d                           False
# 1    ab8cc22e-0f34-4476-bf81-293cbbb2e69c                           False
# 2    ed707a89-a68d-4921-a4cb-16c268e45a5b                           False
# 3    dc2f7685-c3e3-4536-b78b-740479cbb207                           False
# 4    bae9be55-04d4-4641-9781-3d1c4b6950f1                           False
# ..                                    ...                             ...
# 489  f8f12028-2117-4737-9a03-04548ad95e82                           False
# 490                                   577                           False
# 491                                   578                           False
# 492                                   579                           False
# 493                                   582                           False
#
#      has_kiosk region_id eightd_station_services         lon  capacity  \
# 0         True         5                      [] -121.902016        27
# 1         True         5                      [] -121.906834        27
# 2         True         5                      [] -121.883215        23
# 3         True         5                      [] -121.901782        35
# 4         True         5                      [] -121.889937        15
# ..         ...       ...                     ...         ...       ...
# 489       True         3                      [] -122.482786        19
# 490       True       NaN                      [] -122.442729        22
# 491       True       NaN                      [] -122.444305        19
# 492       True         5                      [] -121.871612        25
# 493       True       NaN                      [] -122.455079        18
#
#            lat short_name  eightd_has_key_dispenser  \
# 0    37.350964     SJ-H10                     False
# 1    37.360854     SJ-F10                     False
# 2    37.337122   SJ-M11-2                     False
# 3    37.329732    SJ-M7-1                     False
# 4    37.339301     SJ-L10                     False
# ..         ...        ...                       ...
# 489  37.781929      SF-G7                     False
# 490  37.799175     SF-C18                     False
# 491  37.730655     SF-X16                     False
# 492  37.365088     SJ-H16                     False
# 493  37.803968     SF-A15                     False
#
#                                                  name  \
# 0                                Mission St at 1st St
# 1                            Kerley Dr at Rosemary St
# 2                           San Fernando St at 7th St
# 3                            San Jose Diridon Station
# 4                                    Saint James Park
# ..                                                ...
# 489                            23rd Ave at Clement St
# 490                       Divisadero St at Lombard St
# 491                          Detroit St at Hearst Ave
# 492  Berryessa BART Station (Mabury Rd at Lenfest Rd)
# 493                            Mason St at Halleck St
#
#                               external_id legacy_id     rental_methods  \
# 0    0d730ac1-7ce6-45cf-aca6-b412ea46709d       288  [KEY, CREDITCARD]
# 1    ab8cc22e-0f34-4476-bf81-293cbbb2e69c       395  [KEY, CREDITCARD]
# 2    ed707a89-a68d-4921-a4cb-16c268e45a5b       280  [KEY, CREDITCARD]
# 3    dc2f7685-c3e3-4536-b78b-740479cbb207       312  [KEY, CREDITCARD]
# 4    bae9be55-04d4-4641-9781-3d1c4b6950f1       306  [KEY, CREDITCARD]
# ..                                    ...       ...                ...
# 489  f8f12028-2117-4737-9a03-04548ad95e82       520  [KEY, CREDITCARD]
# 490  82ad4cff-001f-49a8-88fa-a5a63d64b9a2       577  [KEY, CREDITCARD]
# 491  41b2200f-7915-410b-95c6-084bc4d3dee8       578  [KEY, CREDITCARD]
# 492  93d95ded-d49e-43bc-b7fe-6ce556569088       579  [KEY, CREDITCARD]
# 493  35e3bf9b-4c65-4f2b-9d46-32afe9fe82d9       582  [KEY, CREDITCARD]
#
#     station_type
# 0        classic
# 1        classic
# 2        classic
# 3        classic
# 4        classic
# ..           ...
# 489      classic
# 490      classic
# 491      classic
# 492      classic
# 493      classic
#
# [494 rows x 16 columns]
